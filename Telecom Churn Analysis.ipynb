# %%
# importing libraries for analysis and visualisation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# reading in the dataset
df = pd.read_csv(r'C:\Users\hp\Documents\Datasets\telecom.csv')
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS           128.0      415.0                 No             Yes
# 1    OH           107.0      415.0                 No             Yes
# 2    NJ           137.0      415.0                 No              No
# 3    OH            84.0      408.0                Yes              No
# 4    OK            75.0      415.0                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1            110.0
# 1                   26.0              161.6            123.0
# 2                    0.0              243.4            114.0
# 3                    0.0              299.4             71.0
# 4                    0.0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# displays the names of each column
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# to check the number of rows and columns
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# This dataset contains 3,333 rows and 20 columns

# %%
# an overview of the column names, columns and row number, data type of each column, non-null count, etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3330 non-null   float64
#  2   Area code               3331 non-null   float64
#  3   International plan      3328 non-null   object
#  4   Voice mail plan         3332 non-null   object
#  5   Number vmail messages   3332 non-null   float64
#  6   Total day minutes       3330 non-null   float64
#  7   Total day calls         3331 non-null   float64
#  8   Total day charge        3331 non-null   float64
#  9   Total eve minutes       3331 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3330 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3330 non-null   float64
# ...

# %%
# to compute the number nulls in each column in the dataframe
df.isna().sum()
# Out:
# State                     0
# Account length            3
# Area code                 2
# International plan        5
# Voice mail plan           1
# Number vmail messages     1
# Total day minutes         3
# Total day calls           2
# Total day charge          2
# Total eve minutes         2
# Total eve calls           0
# Total eve charge          3
# Total night minutes       0
# Total night calls         3
# Total night charge        3
# Total intl minutes        0
# Total intl calls          1
# Total intl charge         4
# Customer service calls    2
# Churn                     2
# dtype: int64

# %%
# dropping nuls and assigning the new dataframe to 'data'
data = df.dropna()
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# cross checking the sum of nulls in the rows
data.isna().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
# checking for duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# a statistical overview if the numerical columns in the datafranme
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3294.000000  3294.000000            3294.000000        3294.000000
# mean       100.989678   437.182149               8.135094         179.788585
# std         39.866813    42.365590              13.708949          54.377830
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.625000
# 50%        100.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.275000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3294.000000       3294.000000        3294.000000      3294.000000
# mean        100.383424         30.564605         201.076290       100.052520
# ...

# %%
# computing the percentage of users who churned
data['Churn'].value_counts(normalize=True)
# Out:
# Churn
# False    0.855191
# True     0.144809
# Name: proportion, dtype: float64

# %% [markdown]
# ~14.5% of users churned

# %%
# pie chart on churn distribution
data['Churn'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# to compute the numer of unique states in the dataframe
data['State'].nunique()
# Out:
# 51

# %%
# to view all states in the dataframe
data['State'].unique()
# Out:
# array(['KS', 'OH', 'NJ', 'OK', 'AL', 'MA', 'MO', 'LA', 'WV', 'IN', 'RI',
#        'IA', 'MT', 'NY', 'ID', 'VT', 'VA', 'TX', 'FL', 'AZ', 'SC', 'NE',
#        'WY', 'HI', 'IL', 'NH', 'GA', 'AK', 'MD', 'AR', 'WI', 'OR', 'MI',
#        'DE', 'UT', 'CO', 'CA', 'MN', 'SD', 'NC', 'WA', 'NM', 'NV', 'DC',
#        'KY', 'ME', 'MS', 'TN', 'PA', 'CT', 'ND'], dtype=object)

# %%
# the number of unique area codes in the dataframe
data['Area code'].nunique()
# Out:
# 3

# %%
# to view the unique area codes in the dataframe
data['Area code'].unique()
# Out:
# array([415., 408., 510.])

# %%
# distribution of voice mail plan users
data['Voice mail plan'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# univariate analysis on distribution
num = ['Number vmail messages', 'Total day minutes',
       'Total day calls', 'Total day charge', 'Total eve minutes',
       'Total eve calls', 'Total eve charge', 'Total night minutes',
       'Total night calls', 'Total night charge', 'Total intl minutes',
       'Total intl calls', 'Total intl charge', 'Customer service calls']
for col in num:
    plt.hist(df[col])
    plt.title(f'{col} distribution')
    plt.show()

# %% [markdown]
# The right skew in the distrubution of voice mail messages, total international call distribution, and customer service calls suggests most users had less number of voice mail messages, less calls being international calls and more calls being made to the service center.

# %%
# investigating churn and non-churn users wwith International plan
data.groupby(["Churn", "International plan"]).size()
# Out:
# Churn  International plan
# False  No                    2633
#        Yes                    184
# True   No                     340
#        Yes                    137
# dtype: int64

# %%
data.groupby(['Churn', 'Voice mail plan']).size()
# Out:
# Churn  Voice mail plan
# False  No                 1981
#        Yes                 836
# True   No                  398
#        Yes                  79
# dtype: int64

# %%
# Bivariate analysis of Churn and other columns
for col in num:
    print(col)
    print(data.groupby('Churn')[col].sum())
# Out:
# Number vmail messages
# Churn
# False    24362.0
# True      2435.0
# Name: Number vmail messages, dtype: float64
# Total day minutes
# Churn
# False    493483.7
# True      98739.9
# Name: Total day minutes, dtype: float64
# Total day calls
# Churn
# False    282319.0
# True      48344.0
# Name: Total day calls, dtype: float64
# Total day charge
# Churn
# False    83893.77
# True     16786.04
# Name: Total day charge, dtype: float64
# Total eve minutes
# Churn
# False    560936.8
# True     101408.5
# Name: Total eve minutes, dtype: float64
# Total eve calls
# Churn
# False    281633
# True      47940
# Name: Total eve calls, dtype: int64
# Total eve charge
# Churn
# False    47680.28
# True      8619.77
# Name: Total eve charge, dtype: float64
# Total night minutes
# Churn
# False    563617.0
# True      97801.8
# Name: Total night minutes, dtype: float64
# Total night calls
# Churn
# False    281998.0
# True      47999.0
# Name: Total night calls, dtype: float64
# ...

# %% [markdown]
# ### Visualising the above data using Pie Charts

# %%
from matplotlib import rcParams # To modify titles
# Data for each category
labels = ['False', 'True']
data = [
    (24362.0, 2435.0),  # Number vmail messages
    (493483.7, 98739.9),  # Total day minutes
    (282319.0, 48344.0),  # Total day calls
    (83893.77, 16786.04),  # Total day charge
    (560936.8, 101408.5),  # Total eve minutes
    (281633, 47940),  # Total eve calls
    (47680.28, 8619.77),  # Total eve charge
    (563617.0, 97801.8),  # Total night minutes
    (281998.0, 47999.0),  # Total night calls
    (25362.98, 4401.14),  # Total night charge
    (28617.2, 5117.8),  # Total intl minutes
    (12782.0, 1989.0),  # Total intl calls
    (7728.07, 1382.06),  # Total intl charge
    (4087.0, 1059.0)   # Customer service calls
]

titles = [
    "Voicemail Messages", "Day Minutes", "Day Calls", "Day Charge",
    "Evening Minutes", "Evening Calls", "Evening Charge", "Night Minutes",
    "Night Calls", "Night Charge", "Intl Minutes", "Intl Calls",
    "Intl Charge", "Customer Service Calls"
]

# Create subplots
fig, axes = plt.subplots(4, 4, figsize=(15, 15))
axes = axes.flatten()

# Plot each pie chart
for i in range(14):
    axes[i].pie(data[i], labels=labels, autopct='%1.1f%%')
    axes[i].set_title(titles[i], weight='bold')

# to hide the last two empty subplots
for j in range(14, 16):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# Examining averages
for col in num:
    print(col)
    print(data.groupby('Churn')[col].mean())
# Out:
# Number vmail messages
# Churn
# False    8.648207
# True     5.104822
# Name: Number vmail messages, dtype: float64
# Total day minutes
# Churn
# False    175.180582
# True     207.001887
# Name: Total day minutes, dtype: float64
# Total day calls
# Churn
# False    100.219737
# True     101.350105
# Name: Total day calls, dtype: float64
# Total day charge
# Churn
# False    29.781246
# True     35.190860
# Name: Total day charge, dtype: float64
# Total eve minutes
# Churn
# False    199.125595
# True     212.596436
# Name: Total eve minutes, dtype: float64
# Total eve calls
# Churn
# False     99.976216
# True     100.503145
# Name: Total eve calls, dtype: float64
# Total eve charge
# Churn
# False    16.925907
# True     18.070797
# Name: Total eve charge, dtype: float64
# Total night minutes
# Churn
# False    200.077032
# True     205.035220
# Name: Total night minutes, dtype: float64
# Total night calls
# Churn
# False    100.105786
# True     100.626834
# ...

# %% [markdown]
# ### Visualising

# %%
# Data
labels = ['False', 'True']
avg_values = [
    [8.648207, 5.104822],  # Number vmail messages
    [175.180582, 207.001887],  # Total day minutes
    [100.219737, 101.350105],  # Total day calls
    [29.781246, 35.190860],  # Total day charge
    [199.125595, 212.596436],  # Total eve minutes
    [99.976216, 100.503145],  # Total eve calls
    [16.925907, 18.070797],  # Total eve charge
    [200.077032, 205.035220],  # Total night minutes
    [100.105786, 100.626834],  # Total night calls
    [9.003543, 9.226709],  # Total night charge
    [10.15875, 10.72914],  # Total intl minutes
    [4.537451, 4.169811],  # Total intl calls
    [2.743369, 2.897400],  # Total intl charge
    [1.450834, 2.220126],  # Customer service calls
]

titles = [
    'Number Vmail Messages', 'Total Day Minutes', 'Total Day Calls', 'Total Day Charge',
    'Total Eve Minutes', 'Total Eve Calls', 'Total Eve Charge', 'Total Night Minutes',
    'Total Night Calls', 'Total Night Charge', 'Total Intl Minutes', 'Total Intl Calls',
    'Total Intl Charge', 'Customer Service Calls'
]

fig, axes = plt.subplots(4, 4, figsize=(16, 16))  
axes = axes.flatten()

for i in range(len(avg_values)):
    axes[i].pie(avg_values[i], labels=labels, autopct='%1.1f%%')
    axes[i].set_title(titles[i], weight='bold')

for j in range(14, 16):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# Churned customers had longer call durations while maintaining similar call frequency as non-churned customers, suggesting potential engagement in more expensive calling activities such as international or long-distance calls.
# Churned customers contacted customer service significantly more often than their non-churned counterparts, indicating possible service dissatisfaction, unresolved technical issues, or recurring billing concerns.

# %%
# The top ten states with the highest churn rates
state_churn = data.groupby(['State'])['Churn'].value_counts(normalize=True).unstack() 
state_churn_sorted = state_churn.sort_values(by=True , ascending = False)           # Sorts the dataframe by 'True' in descending order
state_churn_sorted.head(10)
# Out:
# Churn     False     True
# State
# CA     0.735294  0.264706
# NJ     0.735294  0.264706
# TX     0.750000  0.250000
# SC     0.762712  0.237288
# MD     0.776119  0.223881
# MS     0.777778  0.222222
# MI     0.777778  0.222222
# WA     0.781250  0.218750
# ME     0.786885  0.213115
# NV     0.787879  0.212121

# %% [markdown]
# New Jersey, California and Texas are the top three states with 26.5% for New Jersey and California, and 25% churn rate for Texas.

# %%
# Examining churn rates in different area codes in the states of New Jersey, california, and Texas.
NJ = data[data['State'] == 'NJ'] # filter the dataframe to slect rows with state NJ
NJ.groupby(['Area code'])['Churn'].value_counts(normalize=True).unstack()
# Out:
# Churn         False     True
# Area code
# 408.0      0.600000  0.400000
# 415.0      0.852941  0.147059
# 510.0      0.631579  0.368421

# %% [markdown]
# The 408 area code in NJ stands out with a higher churn rate (40%) compared to the other area codes. The 415 area code has a much lower churn rate at around 14.7%, while the 510 area code has a churn rate of 36.8%.

# %%
CA = data[data['State'] == 'CA'] # filter the dataframe to slect rows with state CA
CA.groupby(['Area code'])['Churn'].value_counts(normalize=True).unstack()
# Out:
# Churn         False     True
# Area code
# 408.0      0.857143  0.142857
# 415.0      0.705882  0.294118
# 510.0      0.700000  0.300000

# %% [markdown]
# 408 has the lowest churn at 14.3%, and 415 and 510 with higher churn rates.

# %%
TX = data[data['State'] == 'TX'] # filter the dataframe to slect rows with state TX
TX.groupby(['Area code'])['Churn'].value_counts(normalize=True).unstack()
# Out:
# Churn         False     True
# Area code
# 408.0      0.850000  0.150000
# 415.0      0.756757  0.243243
# 510.0      0.600000  0.400000

# %% [markdown]
# In TX, the 510 area code has the highest churn at 40%, followed by 415 with a churn rate of 24.3%. The 408 area code has the lowest churn at 15%.

# %%
SC = data[data['State'] == 'SC'] # filter the dataframe to slect rows with state NJ
SC.groupby(['Area code'])['Churn'].value_counts(normalize=True).unstack()
# Out:
# Churn         False     True
# Area code
# 408.0      0.833333  0.166667
# 415.0      0.766667  0.233333
# 510.0      0.705882  0.294118

# %% [markdown]
# In SC, area code 510 has the highest churn rate at about 29%, followed by area code 415 with around 23%, and area code 408 with the lowest churn at about 17%.

# %% [markdown]
# The area codes with 40% churn rate stands, which is quite high compared to the other areas. This suggests that a large number of customers are leaving, which could point to issues like dissatisfaction with service or better offers from competitors in the area. It is worth paying attention to, as understanding the reasons behind such a high churn could help improve retention in those regions.

# %% [markdown]
# # Key findings

# %% [markdown]
# This analysis revealed three significant correlations between customer behavior and retention:
#
#
# 1. Higher service use is directly associated with higher charges, indicating a strong link between usage and costs.
# 2. Fe internationalwer calls with longer durations suggsnincurement of higher charges,ty, wh isich typicalto international callingtes.
# 3. Increased customer service contact frequency is a strong predictouent churn.omers.

# %% [markdown]
# # Recommendations

# %% [markdown]
# ### Keep high-usage customers happy
# 1. Create service bundles that give customers and freuquent callers loyalty discount and more value for their money.
# 2. Provide personalised deals based on their usage patterns to keep them engaged.
#
# ### Make international calls more affordable
# 1. Introduce discounted international calling plans for popular destinations.
# 2. Offer flexible options like subscription-based international packages.
# 3. Partner with international carriers to bring down costs and improve call quality.
#
# ### Improve customer service to reduce churn
# 1. Train support teams to handle frequent problems more efficiently.
# 2. Be proactive—reach out to customers before small issues turn into big frustrations.t.
